# %% [markdown]
# <i>Author: Timothy Lang (timothy.j.lang@nasa.gov)</i>

# %% [markdown]
# ##### Import needed modules

# %%
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy
import multidop
import pyart
import tempfile
import os
import glob
import time
# %matplotlib inline
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119

# %% [markdown]
# ##### Ingest radar volumes using `pyart`.

# %%
basepath = '/home/rjackson/data/cpol/'
# f1 = glob.glob(basepath +'KHTX/*.uf')
# f2 = glob.glob(basepath +'ARMOR/*.uf')

f1 = '/home/rjackson/pyart_test/corrected_vel_174143KHTX.uf'
f2 = '/home/rjackson/pyart_test/corrected_vel_173943ARMOR.uf'

# %%
r1 = pyart.aux_io.radx.read_radx(f1)
r2 = pyart.aux_io.radx.read_radx(f2)
r1.info('compact')
r2.info('compact')
# Out:
# altitude: <ndarray of type: float64 and shape: (1,)>
# altitude_agl: <ndarray of type: float64 and shape: (1,)>
# antenna_transition: <ndarray of type: int8 and shape: (6120,)>
# azimuth: <ndarray of type: float32 and shape: (6120,)>
# elevation: <ndarray of type: float32 and shape: (6120,)>
# fields:
# 	RE: <ndarray of type: float32 and shape: (6120, 1832)>
# 	SW: <ndarray of type: float32 and shape: (6120, 1832)>
# 	VE: <ndarray of type: float32 and shape: (6120, 1832)>
# fixed_angle: <ndarray of type: float32 and shape: (14,)>
# instrument_parameters:
# 	prt_ratio: <ndarray of type: float32 and shape: (6120,)>
# 	follow_mode: <ndarray of type: |S1 and shape: (14, 32)>
# 	measured_transmit_power_v: <ndarray of type: float32 and shape: (6120,)>
# 	pulse_width: <ndarray of type: float32 and shape: (6120,)>
# 	n_samples: <ndarray of type: int32 and shape: (6120,)>
# 	unambiguous_range: <ndarray of type: float32 and shape: (6120,)>
# 	radar_antenna_gain_v: <ndarray of type: float32 and shape: (1,)>
# 	radar_rx_bandwidth: <ndarray of type: float32 and shape: (1,)>
# 	prt: <ndarray of type: float32 and shape: (6120,)>
# 	radar_antenna_gain_h: <ndarray of type: float32 and shape: (1,)>
# 	frequency: <ndarray of type: float32 and shape: (1,)>
# 	measured_transmit_power_h: <ndarray of type: float32 and shape: (6120,)>
# 	prt_mode: <ndarray of type: |S1 and shape: (14, 32)>
# 	radar_beam_width_h: <ndarray of type: float32 and shape: (1,)>
# 	radar_beam_width_v: <ndarray of type: float32 and shape: (1,)>
# 	polarization_mode: <ndarray of type: |S1 and shape: (14, 32)>
# 	nyquist_velocity: <ndarray of type: float32 and shape: (6120,)>
# latitude: <ndarray of type: float64 and shape: (1,)>
# longitude: <ndarray of type: float64 and shape: (1,)>
# nsweeps: 14
# ngates: 1832
# nrays: 6120
# radar_calibration:
# 	r_calib_receiver_slope_hc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_ldr_correction_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_noise_source_power_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_base_dbz_1km_hx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_xmit_power_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_zdr_correction: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_base_dbz_1km_hc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_xmit_power_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_noise_vx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_noise_source_power_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_ldr_correction_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_slope_vx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_index: <ndarray of type: int32 and shape: (6120,)>
# 	r_calib_dbz_correction: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_sun_power_vc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_antenna_gain_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_pulse_width: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_sun_power_vx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_antenna_gain_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_noise_vc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_sun_power_hc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_slope_vc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_base_dbz_1km_vc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_coupler_forward_loss_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_two_way_radome_loss_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_radar_constant_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_test_power_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_system_phidp: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_sun_power_hx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_test_power_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_two_way_radome_loss_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_radar_constant_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_gain_hx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_base_dbz_1km_vx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_coupler_forward_loss_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_gain_vc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_power_measure_loss_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_mismatch_loss: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_two_way_waveguide_loss_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_noise_hx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_noise_hc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_slope_hx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_two_way_waveguide_loss_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_gain_vx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_power_measure_loss_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_gain_hc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_time: <ndarray of type: |S1 and shape: (1, 32)>
# range: <ndarray of type: float32 and shape: (1832,)>
# scan_rate: <ndarray of type: float32 and shape: (6120,)>
# scan_type: ppi
# sweep_end_ray_index: <ndarray of type: int32 and shape: (14,)>
# sweep_mode: <ndarray of type: |S1 and shape: (14, 32)>
# sweep_number: <ndarray of type: int32 and shape: (14,)>
# sweep_start_ray_index: <ndarray of type: int32 and shape: (14,)>
# target_scan_rate: <ndarray of type: float32 and shape: (14,)>
# time: <ndarray of type: float64 and shape: (6120,)>
# metadata:
# 	comment:
# 	instrument_type: radar
# 	site_name: UNKNOWN
# 	Sub_conventions: CF-Radial instrument_parameters radar_parameters radar_calibration
# 	original_format: UF
# 	references: UNKNOWN
# 	volume_number: 1
# 	scan_id: 0
# 	title:
# 	source: NCAR/RDP
# 	version: CF-Radial-1.3
# 	instrument_name: KHTX
# 	ray_times_increase: true
# 	end_time: 2009-04-10 17:45:59.000
# 	start_datetime: 2009-04-10T17:41:43Z
# 	platform_is_mobile: false
# 	start_time: 2009-04-10 17:41:43.000
# 	driver: RadxConvert(NCAR)
# 	time_coverage_start: 2009-04-10T17:41:43Z
# 	institution:
# 	n_gates_vary: false
# 	primary_axis: axis_z
# 	time_coverage_end: 2009-04-10T17:45:59Z
# 	scan_name:
# 	created: 2016/10/31 17:56:05.537
# 	Conventions: CF-1.6
# 	platform_type: fixed
# 	end_datetime: 2009-04-10T17:45:59Z
# 	history: corrected_vel_174143KHTX.uf
# altitude: <ndarray of type: float64 and shape: (1,)>
# altitude_agl: <ndarray of type: float64 and shape: (1,)>
# antenna_transition: <ndarray of type: int8 and shape: (1769,)>
# azimuth: <ndarray of type: float32 and shape: (1769,)>
# elevation: <ndarray of type: float32 and shape: (1769,)>
# fields:
# 	MD: <ndarray of type: float32 and shape: (1769, 992)>
# 	DM: <ndarray of type: float32 and shape: (1769, 992)>
# 	VE: <ndarray of type: float32 and shape: (1769, 992)>
# 	KD: <ndarray of type: float32 and shape: (1769, 992)>
# 	RH: <ndarray of type: float32 and shape: (1769, 992)>
# 	SW: <ndarray of type: float32 and shape: (1769, 992)>
# 	CD: <ndarray of type: float32 and shape: (1769, 992)>
# 	CZ: <ndarray of type: float32 and shape: (1769, 992)>
# 	VR: <ndarray of type: float32 and shape: (1769, 992)>
# 	DZ: <ndarray of type: float32 and shape: (1769, 992)>
# 	ZT: <ndarray of type: float32 and shape: (1769, 992)>
# 	LR: <ndarray of type: float32 and shape: (1769, 992)>
# 	PH: <ndarray of type: float32 and shape: (1769, 992)>
# 	DR: <ndarray of type: float32 and shape: (1769, 992)>
# 	MZ: <ndarray of type: float32 and shape: (1769, 992)>
# fixed_angle: <ndarray of type: float32 and shape: (16,)>
# instrument_parameters:
# 	prt_ratio: <ndarray of type: float32 and shape: (1769,)>
# 	follow_mode: <ndarray of type: |S1 and shape: (16, 32)>
# 	measured_transmit_power_v: <ndarray of type: float32 and shape: (1769,)>
# 	pulse_width: <ndarray of type: float32 and shape: (1769,)>
# 	n_samples: <ndarray of type: int32 and shape: (1769,)>
# 	unambiguous_range: <ndarray of type: float32 and shape: (1769,)>
# 	radar_antenna_gain_v: <ndarray of type: float32 and shape: (1,)>
# 	radar_rx_bandwidth: <ndarray of type: float32 and shape: (1,)>
# 	prt: <ndarray of type: float32 and shape: (1769,)>
# 	radar_antenna_gain_h: <ndarray of type: float32 and shape: (1,)>
# 	frequency: <ndarray of type: float32 and shape: (1,)>
# 	measured_transmit_power_h: <ndarray of type: float32 and shape: (1769,)>
# 	prt_mode: <ndarray of type: |S1 and shape: (16, 32)>
# 	radar_beam_width_h: <ndarray of type: float32 and shape: (1,)>
# 	radar_beam_width_v: <ndarray of type: float32 and shape: (1,)>
# 	polarization_mode: <ndarray of type: |S1 and shape: (16, 32)>
# 	nyquist_velocity: <ndarray of type: float32 and shape: (1769,)>
# latitude: <ndarray of type: float64 and shape: (1,)>
# longitude: <ndarray of type: float64 and shape: (1,)>
# nsweeps: 16
# ngates: 992
# nrays: 1769
# radar_calibration:
# 	r_calib_receiver_slope_hc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_ldr_correction_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_noise_source_power_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_base_dbz_1km_hx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_xmit_power_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_zdr_correction: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_base_dbz_1km_hc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_xmit_power_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_noise_vx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_noise_source_power_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_ldr_correction_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_slope_vx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_index: <ndarray of type: int32 and shape: (1769,)>
# 	r_calib_dbz_correction: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_sun_power_vc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_antenna_gain_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_pulse_width: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_sun_power_vx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_antenna_gain_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_noise_vc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_sun_power_hc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_slope_vc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_base_dbz_1km_vc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_coupler_forward_loss_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_two_way_radome_loss_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_radar_constant_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_test_power_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_system_phidp: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_sun_power_hx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_test_power_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_two_way_radome_loss_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_radar_constant_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_gain_hx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_base_dbz_1km_vx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_coupler_forward_loss_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_gain_vc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_power_measure_loss_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_mismatch_loss: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_two_way_waveguide_loss_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_noise_hx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_noise_hc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_slope_hx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_two_way_waveguide_loss_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_gain_vx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_power_measure_loss_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_gain_hc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_time: <ndarray of type: |S1 and shape: (1, 32)>
# range: <ndarray of type: float32 and shape: (992,)>
# scan_rate: <ndarray of type: float32 and shape: (1769,)>
# scan_type: sector
# sweep_end_ray_index: <ndarray of type: int32 and shape: (16,)>
# sweep_mode: <ndarray of type: |S1 and shape: (16, 32)>
# sweep_number: <ndarray of type: int32 and shape: (16,)>
# sweep_start_ray_index: <ndarray of type: int32 and shape: (16,)>
# target_scan_rate: <ndarray of type: float32 and shape: (16,)>
# time: <ndarray of type: float64 and shape: (1769,)>
# metadata:
# 	comment:
# 	instrument_type: radar
# 	site_name: UNKNOWN
# 	Sub_conventions: CF-Radial instrument_parameters radar_parameters radar_calibration
# 	original_format: UF
# 	references: UNKNOWN
# 	volume_number: 1
# 	scan_id: 0
# 	title: TRMMGVUF
# 	source: NCAR/RDP
# 	version: CF-Radial-1.3
# 	instrument_name: ARMOR
# 	ray_times_increase: true
# 	end_time: 2009-04-10 17:42:07.000
# 	start_datetime: 2009-04-10T17:39:43Z
# 	platform_is_mobile: false
# 	start_time: 2009-04-10 17:39:43.000
# 	driver: RadxConvert(NCAR)
# 	time_coverage_start: 2009-04-10T17:39:43Z
# 	institution:
# 	n_gates_vary: false
# 	primary_axis: axis_z
# 	time_coverage_end: 2009-04-10T17:42:07Z
# 	scan_name:
# 	created: 2016/10/31 17:56:07.264
# 	Conventions: CF-1.6
# 	platform_type: fixed
# 	end_datetime: 2009-04-10T17:42:07Z
# 	history: corrected_vel_173943ARMOR.uf

# %% [markdown]
# ##### Rename variable fields to be consistent between radars.

# %%
# If you needed to dealias or perform other corrections,
# this would be the time to start doing that.
cp = deepcopy(r1.fields['RE']['data'])
r1.add_field_like('RE', 'DT', cp, replace_existing=True)
cp = deepcopy(r1.fields['VE']['data'])
r1.add_field_like('VE', 'VT', cp, replace_existing=True)

# %%
cp = deepcopy(r2.fields['CZ']['data'])
r2.add_field_like('CZ', 'DT', cp, replace_existing=True)
cp = deepcopy(r2.fields['VR']['data'])
r2.add_field_like('VR', 'VT', cp, replace_existing=True)

# %%
# The analysis engine currently expects the "missing_value" attribute
r1.fields['DT']['missing_value'] = 1.0 * r1.fields['DT']['_FillValue']
r2.fields['DT']['missing_value'] = 1.0 * r2.fields['DT']['_FillValue']
r1.fields['VT']['missing_value'] = 1.0 * r1.fields['VT']['_FillValue']
r2.fields['VT']['missing_value'] = 1.0 * r2.fields['VT']['_FillValue']

# %%
print(r1.fields['VT']['_FillValue'])
# Out:
# -32768

# %% [markdown]
# ##### Now grid the volumes and add azimuths and elevations afterward.

# %%
def grid_radar(radar, grid_shape=(20, 301, 301), xlim=(-150000, 150000),
               ylim=(-150000, 150000), zlim=(1000, 20000),
               fields=['DT', 'VT'], origin=None):
    bt = time.time()
    radar_list = [radar]
    if origin is None:
        origin = (radar.latitude['data'][0],
                  radar.longitude['data'][0])
    grid = pyart.map.grid_from_radars(
        radar_list, grid_shape=grid_shape,
        grid_limits=(zlim, ylim, xlim),
        grid_origin=origin, fields=fields,
        gridding_algo='map_gates_to_grid', grid_origin_alt=0.0)
    print(time.time()-bt, 'seconds to grid radar')
    return grid

# %%
g1 = grid_radar(r1, origin=(r2.latitude['data'][0], r2.longitude['data'][0]),
                xlim=(-100000, 50000), ylim=(0, 150000), grid_shape=(20, 151, 151))
g2 = grid_radar(r2, origin=(r2.latitude['data'][0], r2.longitude['data'][0]),
                xlim=(-100000, 50000), ylim=(0, 150000), grid_shape=(20, 151, 151))
# Out:
# 7.98566603661 seconds to grid radar
# 3.45238304138 seconds to grid radar

# %%
# The analysis engine requires azimuth and elevation to be part of the grid.
# This information is computed from the grid geometry.
g1 = multidop.angles.add_azimuth_as_field(g1)
g2 = multidop.angles.add_azimuth_as_field(g2)
g1 = multidop.angles.add_elevation_as_field(g1)
g2 = multidop.angles.add_elevation_as_field(g2)

# %%
# Save the input grids for later.
pyart.io.write_grid('khtx_supercell.nc', g1)
pyart.io.write_grid('armor_supercell.nc', g2)

# %% [markdown]
# ##### Now set up and execute the multi-Doppler processing. Save the output to a `pyart`-compatible CF grid.

# %%
# You don't have to define everything. Most of these keywords are default values.
# If you don't define something the program will provide a default value.
# Check parameters.py for what keyword default values are.
localfile = tempfile.NamedTemporaryFile()
pd = {'dir': './',
      'x': [-100000.0, 1000.0, 151],
      'y': [0.0, 1000.0, 151],
      'z': [1000.0, 1000.0,  20],
      'grid': [g1.origin_longitude['data'][0], g1.origin_latitude['data'][0], 0.0],
      'files': ['khtx_supercell.nc',
                'armor_supercell.nc'],
      'radar_names': ['KHTX', 'ARMOR'],
      'refl': 'DT',  # Name of reflectivity field. Must be common between radars.
      'vt': 'VT',  # Name of velocity field. Must be common between radars.
      'bgfile': None,
      'writeout': localfile.name,
      'min_cba': 20.0,  # Minimum beam-crossing angle
      'calc_params': 'calc_example.dda',
      'anel': 1,
      'laplace': 0,
      'read_dataweights': 2,
      'max_dist': 10.0,
      'cutoff': 0.0,
      'UT': 0.0,
      'VT': 0.0,
      'output_error': 0,
      'weak_height': -1,
      'upper_bc': 1,
      'itmax_frprmn': [200, 10],
      'itmax_dbrent': 200,
      'C1b': 1.0,  # Data weighting factor
      'C2b': 10.0,  # Mass continuity weighting factor
      'C3b': 0.0,  # Vorticity weighting factor
      'C4b': 1.0,  # Horizontal smoothing factor
      'C5b': 1.0,  # Vertical smoothing factor
      'C8b': 0.0,  # Sounding factor
      'vary_weights': 0,
      'filter': ['none', '', ''],
      'cvg_opt_bg': [1, 1, 1],
      'cvg_sub_bg': [0, 0, 0],
      'cvg_opt_fil': [0, 1, 1],
      'cvg_sub_fil': [0, 0, 0],
      'cvg_bg': [0, 0, 0],
      'cvg_fil': [0, 0, 0],
      'sseq_trip': [1.0, 1.0, 0.0]
     }
pf = multidop.parameters.ParamFile(pd, 'example.dda')
pf = multidop.parameters.CalcParamFile(pd, 'calc_example.dda')

# %%
# Unfortunately, text output from the analysis engine (DDA) will not display
# until after the program completes. Expect this step to take several minutes.
bt = time.time()
multidop.execute.do_analysis('example.dda')
print((time.time()-bt)/60.0, 'minutes to process')
# Out:
# DDA 0.8.2
# ./DDA: reading calculation parameters from calc_example.dda.
# Changing working directory to ./
# x: -100000.000000 to 50000.000000 in 150 steps of 1000.000000
# y: 0.000000 to 150000.000000 in 150 steps of 1000.000000
# z: 1000.000000 to 20000.000000 in 19 steps of 1000.000000
# z_min=1000, cutoff=0
# UT=0, VT=0
# Anelastic mass cons
# First-order smoothness constraint
# Minimum beam crossing angle = 20 degrees
# Py-ART grids for analyis and all radars must match to within (dx, dy, dz) < (10 10 10) meters.
# Reading Py-ART filekhtx_supercell.nc
# armor_supercell.nc
#
# Radar positions:  (62656.4,31821.4) (0.123459,-0.013841)
# Computing coverage: 155907 verification points out of 456020 total points.
# radar0 249854 obs. radar1 163806 obs. 413660 total obs.
# Analyzed obs = 413660. Mean Vr = 23.4908
# C1b=1 C2b=10 C3b=0 C4b=1 C5b=1 C6b=1 C7b=1 C8b=0
# C2a=10 C3a=0 C4a=1 C5a=1 C6a=1 C7a=1 C8a=0
# Weighting all obs equally!
# GradCheck: rchek = 1e+10. fx1 = 281865
# GradCheck: gxnn = 2979.22
# GradCheck: j = 1. fx2 = 9.247e+18. ffff = 3.104e+06
# GradCheck: j = 2. fx2 = 9.247e+16. ffff = 3.104e+05
# GradCheck: j = 3. fx2 = 9.247e+14. ffff = 3.104e+04
# GradCheck: j = 4. fx2 = 9.25e+12. ffff = 3105
# GradCheck: j = 5. fx2 = 9.276e+10. ffff = 311.4
# GradCheck: j = 6. fx2 = 9.547e+08. ffff = 32.04
# GradCheck: j = 7. fx2 = 1.251e+07. ffff = 4.104
# GradCheck: j = 8. fx2 = 6.723e+05. ffff = 1.31
# GradCheck: j = 9. fx2 = 3.126e+05. ffff = 1.031
# GradCheck: j = 10. fx2 = 2.849e+05. ffff = 1.003
# GradCheck: j = 11. fx2 = 2.822e+05. ffff = 1
# GradCheck: j = 12. fx2 = 2.819e+05. ffff = 1
# GradCheck: j = 13. fx2 = 2.819e+05. ffff = 1
# GradCheck: j = 14. fx2 = 2.819e+05. ffff = 1
# GradCheck: j = 15. fx2 = 2.819e+05. ffff = 1
# GradCheck: j = 16. fx2 = 2.819e+05. ffff = 1
# GradCheck: j = 17. fx2 = 2.819e+05. ffff = 1
# GradCheck: j = 18. fx2 = 2.819e+05. ffff = 1
# GradCheck: j = 19. fx2 = 2.819e+05. ffff = 1.001
# GradCheck: j = 20. fx2 = 2.819e+05. ffff = 0.9855
# GradCheck: j = 21. fx2 = 2.819e+05. ffff = 0.9359
# GradCheck: j = 22. fx2 = 2.819e+05. ffff = 0.7424
# GradCheck: j = 23. fx2 = 2.819e+05. ffff = 0.7815
# GradCheck: j = 24. fx2 = 2.819e+05. ffff = 1.954
# GradCheck: j = 25. fx2 = 2.819e+05. ffff = 0
# GradCheck: j = 26. fx2 = 2.819e+05. ffff = 0
# GradCheck: j = 27. fx2 = 2.819e+05. ffff = 0
# GradCheck: j = 28. fx2 = 2.819e+05. ffff = 0
# GradCheck: j = 29. fx2 = 2.819e+05. ffff = 0
# GradCheck: j = 30. fx2 = 2.819e+05. ffff = 0
#
# GradCheck: If above is all nan, trouble is coming.
#
# C2b = 10 C5b = 1 Not varying weights.
# xp: 0 0 0 0 0 0
# Starting minimization....
# Its| MsCnsErr|  NrmzErr|AvgObsErr| MxObsErr|   ObsTot|MsConsTot|  SmthTot|  VortTot|  MaxDiff|     MaxW
# 10|9.979e-05|   0.8339| 0.008782|    3.374|    0.325|   0.2215|   0.4535|        0|     10.2|    6.815
# 20|5.825e-05|   0.6936| 0.002791|    1.063|  0.05743|   0.2383|   0.7043|        0|     10.2|     10.3
# 30|2.892e-05|   0.5834| 0.001836|    1.063|  0.03432|   0.1948|   0.7709|        0|    11.33|    18.62
# 40|2.061e-05|   0.5643| 0.001286|   0.6171|  0.02128|    0.187|   0.7917|        0|    10.27|    16.53
# 50|1.597e-05|   0.5324|0.0009753|   0.6497|  0.01455|   0.1716|   0.8138|        0|    7.224|    17.49
# 60| 1.38e-05|   0.5101|0.0007908|   0.5415|  0.01093|   0.1634|   0.8257|        0|    6.797|    21.25
# 70|1.206e-05|   0.4836|0.0006983|   0.5161| 0.009501|   0.1551|   0.8354|        0|    5.817|    25.98
# 80| 1.07e-05|   0.4579|0.0006362|   0.5492| 0.008619|   0.1474|    0.844|        0|    4.785|    28.14
# 90|9.775e-06|   0.4393|0.0006181|   0.5407| 0.008762|    0.141|   0.8502|        0|    3.857|    30.24
# 100|9.284e-06|   0.4303|0.0005906|   0.4792| 0.008519|   0.1369|   0.8546|        0|    3.573|    30.99
# 110|8.995e-06|   0.4262|0.0005912|   0.5263| 0.008998|   0.1336|   0.8574|        0|    2.761|    31.59
# 120| 8.81e-06|   0.4238|0.0005774|   0.5168| 0.008982|   0.1317|   0.8593|        0|    3.076|     33.3
# 130|8.663e-06|   0.4217|0.0005864|   0.5304| 0.009648|     0.13|   0.8604|        0|    2.829|    33.41
# 140|8.549e-06|     0.42|0.0005816|   0.5948| 0.009834|   0.1288|   0.8613|        0|    2.544|     33.4
# 150|8.511e-06|   0.4202|0.0005645|   0.6594| 0.009558|   0.1286|   0.8618|        0|    2.023|    33.11
# 160| 8.49e-06|   0.4211|0.0005682|   0.6936|  0.00995|   0.1287|   0.8614|        0|    1.562|    33.14
# 170|8.559e-06|    0.424|0.0005448|   0.7231| 0.009369|     0.13|   0.8606|        0|    1.349|    33.33
# 180|8.571e-06|   0.4253|0.0005403|   0.7454| 0.009427|    0.131|   0.8596|        0|    1.295|     33.1
# 190|8.562e-06|    0.426|0.0005213|   0.7374| 0.008963|   0.1319|   0.8591|        0|    1.251|    32.63
# 200|8.558e-06|   0.4265| 0.000514|   0.7006| 0.008891|   0.1329|   0.8582|        0|    1.231|    32.36
#
# DONE
# stop=1 iterations=200 itmax2=200
# Convergence criteria met.
# ITS == 200
# Finished
# C2b = 10 C5b = 1 Not varying weights.
# xp: 40.9453 41.1209 41.1536 41.2237 41.1919 41.2012
# Filter applied
# C2b = 10 C5b = 1 Not varying weights.
# xp: 40.9453 41.1209 41.1536 41.2237 41.1919 41.2012
# GradCheck: rchek = 1e+10. fx1 = 8.32325e+08
# GradCheck: gxnn = 2.31275e+11
# GradCheck: j = 1. fx2 = 6.005e+31. ffff = 2.596e+11
# GradCheck: j = 2. fx2 = 6.005e+29. ffff = 2.596e+10
# GradCheck: j = 3. fx2 = 6.005e+27. ffff = 2.596e+09
# GradCheck: j = 4. fx2 = 6.005e+25. ffff = 2.596e+08
# GradCheck: j = 5. fx2 = 6.005e+23. ffff = 2.596e+07
# GradCheck: j = 6. fx2 = 6.005e+21. ffff = 2.596e+06
# GradCheck: j = 7. fx2 = 6.005e+19. ffff = 2.596e+05
# GradCheck: j = 8. fx2 = 6.005e+17. ffff = 2.596e+04
# GradCheck: j = 9. fx2 = 6.007e+15. ffff = 2597
# GradCheck: j = 10. fx2 = 6.028e+13. ffff = 260.6
# GradCheck: j = 11. fx2 = 6.244e+11. ffff = 26.96
# GradCheck: j = 12. fx2 = 9.15e+09. ffff = 3.596
# GradCheck: j = 13. fx2 = 1.124e+09. ffff = 1.26
# GradCheck: j = 14. fx2 = 8.561e+08. ffff = 1.026
# GradCheck: j = 15. fx2 = 8.346e+08. ffff = 1.003
# GradCheck: j = 16. fx2 = 8.326e+08. ffff = 1
# GradCheck: j = 17. fx2 = 8.323e+08. ffff = 1
# GradCheck: j = 18. fx2 = 8.323e+08. ffff = 1
# GradCheck: j = 19. fx2 = 8.323e+08. ffff = 0.9994
# GradCheck: j = 20. fx2 = 8.323e+08. ffff = 1
# GradCheck: j = 21. fx2 = 8.323e+08. ffff = 1.02
# GradCheck: j = 22. fx2 = 8.323e+08. ffff = 1.548
# GradCheck: j = 23. fx2 = 8.323e+08. ffff = 0.7646
# GradCheck: j = 24. fx2 = 8.323e+08. ffff = 0.7099
# GradCheck: j = 25. fx2 = 8.323e+08. ffff = -0.0268
# GradCheck: j = 26. fx2 = 8.323e+08. ffff = 0
# GradCheck: j = 27. fx2 = 8.323e+08. ffff = 0
# GradCheck: j = 28. fx2 = 8.323e+08. ffff = 0
# GradCheck: j = 29. fx2 = 8.323e+08. ffff = 0
# GradCheck: j = 30. fx2 = 8.323e+08. ffff = 0
#
# GradCheck: If above is all nan, trouble is coming.
#
# Its| MsCnsErr|  NrmzErr|AvgObsErr| MxObsErr|   ObsTot|MsConsTot|  SmthTot|  VortTot|  MaxDiff|     MaxW
# 10| 5.74e-07|   0.8243|   0.3512|    38.94| 0.001245|3.149e-09|   0.9988|        0|    22.31|    15.05
#
# DONE
# stop=1 iterations=10 itmax2=10
# Convergence criteria met.
# ITS == 10
# Finished
# 30.7707 30.7845 30.7353 30.8687 30.9259 31.118
# 3.56188198328 minutes to process

# %%
# Baseline output is not CF or Py-ART compliant. This function fixes that.
# This is why we wrote the original output to a tempfile that can be safely removed.
# The final grid will have all wind solutions outside the coverage region masked.
fname = 'cf_compliant_grid.nc'
final_grid = multidop.grid_io.make_new_grid([g2, g1], localfile.name)
final_grid.write(fname)
localfile.close()

# %% [markdown]
# ##### Finally, let's check the results!

# %%
pyart_grid = pyart.io.read_grid(fname)
print(pyart_grid.fields.keys())
# Out:
# [u'eastward_wind', u'reflectivity', u'upward_air_velocity', u'northward_wind']

# %%
cs = plt.pcolormesh(0.001*pyart_grid.x['data'], 0.001*pyart_grid.y['data'],
                    np.amax(pyart_grid.fields['upward_air_velocity']['data'], axis=0),
                    vmin=0, vmax=40, cmap='PuRd')
plt.colorbar(cs, label='Max W (m/s)')

# %%
fig = plt.figure(figsize=(12, 10))
DZcomp = np.amax(pyart_grid.fields['reflectivity']['data'], axis=0)
x, y = np.meshgrid(0.001*pyart_grid.x['data'], 0.001*pyart_grid.y['data'])
cs = plt.pcolormesh(0.001*pyart_grid.x['data'], 0.001*pyart_grid.y['data'],
                    DZcomp, vmin=0, vmax=75, cmap='pyart_NWSRef')
Wcomp = np.amax(pyart_grid.fields['upward_air_velocity']['data'], axis=0)
plt.contour(x, y, Wcomp, levels=[10, 20, 30, 40], colors=['k', 'k', 'k'])
plt.xlim(-100, 50)
plt.ylim(0, 150)
plt.colorbar(cs, label='Reflectivity (dBZ)')
plt.title('Max Reflectivity (filled) and Updrafts (black, 10 m/s)')
plt.xlabel('Distance east of ARMOR (km)')
plt.ylabel('Distance north of ARMOR (km)')

# %%
thin = 12
ilev = 7
plt.barbs(x[::thin, ::thin], y[::thin, ::thin],
          pyart_grid.fields['eastward_wind']['data'][ilev][::thin, ::thin],
          pyart_grid.fields['northward_wind']['data'][ilev][::thin, ::thin])

# %%
from mpl_toolkits.basemap import cm
lwys = cm.GMT_wysiwyg

ind = 5

U = pyart_grid.fields['eastward_wind']['data']
V = pyart_grid.fields['northward_wind']['data']
W = pyart_grid.fields['upward_air_velocity']['data']

Z = pyart_grid.fields['reflectivity']['data']

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)
cs = ax.pcolormesh(0.001*pyart_grid.x['data'], 0.001*pyart_grid.y['data'],
                   Z[ind], vmin=0, vmax=65, cmap=lwys)

x, y = np.meshgrid(0.001*pyart_grid.x['data'], 0.001*pyart_grid.y['data'])
cl = plt.contour(x, y, W[ind], levels=[10, 20, 30, 40], colors=['k'], linewidths=2,
                 label='Updraft (every 10 m/s)')
plt.clabel(cl, inline=1, fontsize=10, fmt='%1.0f', inline_spacing=0.01)

thin = 2
Um = np.median(U[ind])
Vm = np.median(V[ind])

print(Um, Vm)
ax.barbs(x[::thin, ::thin], y[::thin, ::thin], U[ind][::thin, ::thin]-Um,
         V[ind][::thin, ::thin]-Vm, pivot='middle', color='brown', length=6,
         sizes=dict(emptybarb=0), label='Horizontal Winds (m/s)')

plt.colorbar(cs, label='Reflectivity (dBZ)', ax=ax)

ax.set_xlim(-20, 20)
ax.set_ylim(60, 100)
ax.set_xlabel('Distance East of ARMOR (km)')
ax.set_ylabel('Distance North of ARMOR (km)')
ax.set_title('KHTX/ARMOR U & V Anomalies, W (contours, m/s),' +
             ' & dBZ @ '+str(ind+1)+' km MSL')
plt.legend(loc='upper right')
# Out:
# 24.5417818924 7.33762849972
