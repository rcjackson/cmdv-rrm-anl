# %% [markdown]
# ## RMSE viewer

# %%
import netCDF4
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
file = '/home/rjackson/data/RMSE_CRSIM_lores_2radars.cdf'
dset = netCDF4.Dataset(file)

# %%
dset.variables.keys()
# Out:
# odict_keys(['Co', 'Cm', 'Cv', 'rmse_u', 'rmse_v', 'rmse_w'])

# %%
dset['rmse_u'][:].shape
# Out:
# /home/rjackson/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: RuntimeWarning: invalid value encountered in greater
#   if __name__ == '__main__':
# (15, 15, 15, 41)

# %%
Cv_index = 0
Cv = dset['Cv'][:]
Co = dset['Co'][:]
Cm = dset['Cm'][:]
rmse_u = dset['rmse_u'][:]
rmse_v = dset['rmse_v'][:]
rmse_w = dset['rmse_w'][:]
print(Co[0])
# Out:
# 0.01
# /home/rjackson/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: RuntimeWarning: invalid value encountered in greater
# /home/rjackson/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:6: RuntimeWarning: invalid value encountered in greater
# /home/rjackson/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:7: RuntimeWarning: invalid value encountered in greater

# %%
print(rmse_w[14,12,:, 5])
print(rmse_w.max())
# Out:
# [1.12806967 1.12806963 1.12806957 1.12806949 1.12806937 1.12806922
#  1.128069   1.1280687  1.12806828 1.12806769 1.12806688 1.12806575
#  1.12806418 1.128062   1.12805898]
# nan
# /home/rjackson/anaconda3/lib/python3.5/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)

# %%
x,y = np.meshgrid(np.log10(Co), np.log10(Cm))
fig, ax = plt.subplots(4,3, figsize=(13,12))
c = ax[0,0].contourf(x,y, rmse_u[:,:,Cv_index, 20].T, levels=np.arange(0,10,1), cmap='coolwarm', vmin=0, vmax=10)
ax[0,0].set_ylabel('$log_{10} \ C_{m}$ ')
ax[0,0].set_xticks([-2, -1, 0, 1])
ax[0,0].set_xticklabels(['0.01', '0.1', '1', '10'])

plt.colorbar(c, ax=ax[0,0], label='RMSE [m/s]')
ax[0,0].set_title('RMSE u Height = 10 km')
c = ax[1,0].contourf(x,y, rmse_u[:,:,Cv_index, 15].T, levels=np.arange(0,10,1), cmap='coolwarm', vmin=0, vmax=10)
ax[1,0].set_ylabel('$log_{10} \ C_{m}$ ')
ax[1,0].set_xticks([-2, -1, 0, 1])
ax[1,0].set_xticklabels(['0.01', '0.1', '1', '10'])
plt.colorbar(c, ax=ax[1,0], label='RMSE [m/s]')
ax[1,0].set_title('RMSE u Height = 7.5 km')
c = ax[2,0].contourf(x,y, rmse_u[:,:,Cv_index, 10].T, levels=np.arange(0,10,1), cmap='coolwarm', vmin=0, vmax=10)
ax[2,0].set_ylabel('$log_{10} \ C_{m}$ ')
ax[2,0].set_xticks([-2, -1, 0, 1])
ax[2,0].set_xticklabels(['0.01', '0.1', '1', '10'])
plt.colorbar(c, ax=ax[2,0], label='RMSE [m/s]')
ax[2,0].set_title('RMSE u Height = 5 km')
c = ax[3,0].contourf(x,y, rmse_u[:,:,Cv_index, 5].T, levels=np.arange(0,10,1), cmap='coolwarm', vmin=0, vmax=10)
ax[3,0].set_xlabel('$C_{o}$')
ax[3,0].set_ylabel('$log_{10} \ C_{m}$ ')
ax[3,0].set_xticks([-2, -1, 0, 1])
ax[3,0].set_xticklabels(['0.01', '0.1', '1', '10'])
plt.colorbar(c, ax=ax[3,0], label='RMSE [m/s]')
ax[3,0].set_title('RMSE u Height = 2.5 km')

c = ax[0,1].contourf(x,y, rmse_v[:,:,Cv_index, 20].T, levels=np.arange(0,10,1), cmap='coolwarm', vmin=0, vmax=10)
ax[0,1].set_ylabel('$log_{10} \ C_{m}$ ')
ax[0,1].set_xticks([-2, -1, 0, 1])
ax[0,1].set_xticklabels(['0.01', '0.1', '1', '10'])
plt.colorbar(c, ax=ax[0,1], label='RMSE [m/s]')
ax[0,1].set_title('RMSE v Height = 10 km')
c = ax[1,1].contourf(x,y, rmse_v[:,:,Cv_index, 15].T, levels=np.arange(0,10,1), cmap='coolwarm', vmin=0, vmax=10)
ax[1,1].set_ylabel('$log_{10} \ C_{m}$ ')
ax[1,1].set_xticks([-2, -1, 0, 1])
ax[1,1].set_xticklabels(['0.01', '0.1', '1', '10'])
plt.colorbar(c, ax=ax[1,1], label='RMSE [m/s]')
ax[1,1].set_title('RMSE v Height = 7.5 km')
c = ax[2,1].contourf(x,y, rmse_v[:,:,Cv_index, 10].T, levels=np.arange(0,10,1), cmap='coolwarm', vmin=0, vmax=10)
ax[2,1].set_ylabel('$log_{10} \ C_{m}$ ')
ax[2,1].set_xticks([-2, -1, 0, 1])
ax[2,1].set_xticklabels(['0.01', '0.1', '1', '10'])
plt.colorbar(c, ax=ax[2,1], label='RMSE [m/s]')
ax[2,1].set_title('RMSE v Height = 5 km')
c = ax[3,1].contourf(x,y, rmse_v[:,:,Cv_index, 5].T, levels=np.arange(0,10,1), cmap='coolwarm', vmin=0, vmax=10)
ax[3,1].set_xlabel('$C_{o}$')
ax[3,1].set_ylabel('$log_{10} \ C_{m}$ ')
ax[3,1].set_xticks([-2, -1, 0, 1])
ax[3,1].set_xticklabels(['0.01', '0.1', '1', '10'])
plt.colorbar(c, ax=ax[3,1], label='RMSE [m/s]')
ax[3,1].set_title('RMSE v Height = 2.5 km')

c = ax[0,2].contourf(x,y, rmse_w[:,:,Cv_index, 20].T, levels=np.arange(0,10,1), cmap='coolwarm', vmin=0, vmax=10)
ax[0,2].set_ylabel('$log_{10} \ C_{m}$ ')
ax[0,2].set_xticks([-2, -1, 0, 1])
ax[0,2].set_xticklabels(['0.01', '0.1', '1', '10'])
plt.colorbar(c, ax=ax[0,2], label='RMSE [m/s]')
ax[0,2].set_title('RMSE w Height = 10 km')
c = ax[1,2].contourf(x,y, rmse_w[:,:,Cv_index, 15].T, levels=np.arange(0,10,1), cmap='coolwarm', vmin=0, vmax=10)
ax[1,2].set_ylabel('$log_{10} \ C_{m}$ ')
ax[1,2].set_xticks([-2, -1, 0, 1])
ax[1,2].set_xticklabels(['0.01', '0.1', '1', '10'])
plt.colorbar(c, ax=ax[1,2], label='RMSE [m/s]')
ax[1,2].set_title('RMSE w Height = 7.5 km')
c = ax[2,2].contourf(x,y, rmse_w[:,:,Cv_index, 10].T, levels=np.arange(0,10,1), cmap='coolwarm', vmin=0, vmax=10)
ax[2,2].set_ylabel('$log_{10} \ C_{m}$ ')
ax[2,2].set_xticks([-2, -1, 0, 1])
ax[2,2].set_xticklabels(['0.01', '0.1', '1', '10'])
plt.colorbar(c, ax=ax[2,2], label='RMSE [m/s]')
ax[2,2].set_title('RMSE w Height = 5 km')
c = ax[3,2].contourf(x,y, rmse_w[:,:,Cv_index, 5].T, levels=np.arange(0,10,1), cmap='coolwarm', vmin=0, vmax=10)
ax[3,2].set_xlabel('$C_{o}$')
ax[3,2].set_ylabel('$log_{10} \ C_{m}$ ')
ax[3,2].set_xticks([-2, -1, 0, 1])
ax[3,2].set_xticklabels(['0.01', '0.1', '1', '10'])
plt.colorbar(c, ax=ax[3,2], label='RMSE [m/s]')
ax[3,2].set_title('RMSE w Height = 2.5 km')
# Out:
# /home/rjackson/anaconda3/lib/python3.5/site-packages/numpy/ma/core.py:6442: MaskedArrayFutureWarning: In the future the default for ma.minimum.reduce will be axis=0, not the current None, to match np.minimum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# /home/rjackson/anaconda3/lib/python3.5/site-packages/numpy/ma/core.py:6442: MaskedArrayFutureWarning: In the future the default for ma.maximum.reduce will be axis=0, not the current None, to match np.maximum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)

# %%
fig, ax = plt.subplots(1)
ax.plot(Cm, rmse_w[7,:,Cv_index, 5], label='2.5 km')
ax.plot(Cm, rmse_w[7,:,Cv_index, 10], label='5 km')
ax.plot(Cm, rmse_w[7,:,Cv_index, 15], label='7.5 km')
ax.plot(Cm, rmse_w[7,:,Cv_index, 20], label='10 km')
ax.set_ylim([0, 16])
ax.legend(loc='best')
ax.set_xscale('log')
ax.set_xlabel('Mass continuity constraint')
ax.set_ylabel('RMSE w [m/s]')

# %%
fig, ax = plt.subplots(1)
ax.plot(Cm, rmse_u[7,:,Cv_index, 5], label='2.5 km')
ax.plot(Cm, rmse_u[7,:,Cv_index, 10], label='5 km')
ax.plot(Cm, rmse_u[7,:,Cv_index, 15], label='7.5 km')
ax.plot(Cm, rmse_u[7,:,Cv_index, 20], label='10 km')
ax.legend(loc='best')
ax.set_ylim([0,6])
ax.set_xscale('log')
ax.set_xlabel('Mass continuity constraint')
ax.set_ylabel('RMSE u [m/s]')

# %%
fig, ax = plt.subplots(1)
ax.plot(Cm, rmse_v[7,:,Cv_index, 5], label='2.5 km')
ax.plot(Cm, rmse_v[7,:,Cv_index, 10], label='5 km')
ax.plot(Cm, rmse_v[7,:,Cv_index, 15], label='7.5 km')
ax.plot(Cm, rmse_v[7,:,Cv_index, 20], label='10 km')
ax.legend(loc='best')
ax.set_ylim([0,7])
ax.set_xscale('log')
ax.set_xlabel('Mass continuity constraint')
ax.set_ylabel('RMSE v [m/s]')

# %%
fig, ax = plt.subplots(1)
ax.plot(Co, rmse_v[:,7,Cv_index, 5], label='2.5 km')
ax.plot(Co, rmse_v[:,7,Cv_index, 10], label='5 km')
ax.plot(Co, rmse_v[:,7,Cv_index, 15], label='7.5 km')
ax.plot(Co, rmse_v[:,7,Cv_index, 20], label='10 km')
ax.legend()
ax.set_xscale('log')
ax.set_xlabel('Data constraint')
ax.set_ylabel('RMSE v [m/s]')
