# %% [markdown]
# ## SST data as a function of MJO, monsoon

# %%
import xarray
import pandas

# %%
sst_dataset = xarray.open_dataset('/home/rjackson/data/IMOS_aggregation_20181128T154948Z.nc')
sst_dataset
# Out:
# <xarray.Dataset>
# Dimensions:                  (lat: 127, lon: 127, time: 6727)
# Coordinates:
#   * lat                      (lat) float32 -10.47 -10.49 -10.51 -10.53 ...
#   * lon                      (lon) float32 129.65 129.67 129.69 129.71 ...
#   * time                     (time) datetime64[ns] 1998-10-31T21:20:00 ...
# Data variables:
#     sea_surface_temperature  (time, lat, lon) float32 ...
#     sst_dtime                (time, lat, lon) float32 ...
#     dt_analysis              (time, lat, lon) float32 ...
#     satellite_zenith_angle   (time, lat, lon) float32 ...
#     l2p_flags                (time, lat, lon) float32 ...
#     quality_level            (time, lat, lon) float32 ...
#     sses_bias                (time, lat, lon) float32 ...
#     sses_standard_deviation  (time, lat, lon) float32 ...
#     sses_count               (time, lat, lon) float32 ...
# Attributes:
#     title:                            IMOS L3S Day and Night gridded multiple...
#     summary:                          A merged, day+night, multi-sensor L3S f...
#     institution:                      ABOM
#     license:                          GHRSST protocol describes data use as f...
#     id:                               AVHRR_D-ABOM-L3S-v02.0
#     naming_authority:                 org.ghrsst
#     uuid:                             f30bb9c6-395a-40fe-84d8-5d6ab65d0841
#     gds_version_id:                   2.0r4
#     netcdf_version_id:                4.2.1.1
#     date_created:                     20141108T072053Z
#     file_quality_level:               3
#     spatial_resolution:               0.02 deg
#     start_time:                       1998-10-31T21:20:00Z
#     time_coverage_start:              1998-10-31T21:20:00Z
#     stop_time:                        2017-05-01T21:20:00Z
#     time_coverage_end:                2017-05-01T21:20:00Z
#     northernmost_latitude:            -10.470000267028809
#     southernmost_latitude:            -12.989999771118164
#     easternmost_longitude:            132.1699981689453
#     westernmost_longitude:            129.64999389648438
#     source:                           wind_source=ECMWF_interim_reanalysis,an...
#     platform:                         NOAA-14;NOAA-12
#     sensor:                           AVHRR
#     Metadata_Conventions:             Unidata Dataset Discovery v1.0
#     Metadata_Link:                    TBA
#     keywords:                         Oceans > Ocean Temperature > Sea Surfac...
#     keywords_vocabulary:              NASA Global Change Master Directory (GC...
#     standard_name_vocabulary:         NetCDF Climate and Forecast (CF) Metada...
#     geospatial_lat_units:             degrees_north
#     geospatial_lon_units:             degrees_east
#     geospatial_lat_resolution:        0.02
#     geospatial_lon_resolution:        0.02
#     creator_name:                     Australian Bureau of Meteorology
#     creator_email:                    ghrsst@bom.gov.au
#     project:                          Group for High Resolution Sea Surface T...
#     publisher_name:                   The GHRSST Project Office
#     publisher_email:                  ghrsst-po@nceo.ac.uk
#     publisher_url:                    http://www.ghrsst.org
#     processing_level:                 L3S
#     cdm_data_type:                    grid
#     references:                       http://imos.org.au/sstproducts.html
#     creator_url:                      http://imos.org.au
#     product_version:                  2.0
#     comment:                          HRPT AVHRR experimental L3 retrieval pr...
#     Conventions:                      CF-1.6
#     acknowledgment:                   Any use of these data requires the foll...
#     compliance_checks_passed:         cf ghrsst:1.0
#     compliance_checker_version:       2.3.1
#     compliance_checker_imos_version:  1.1.1
#     history:                          platform_counts=NOAA-14=12;NOAA-12=12,q...

# %%
sst_dataset.sea_surface_temperature.mean(axis=0).plot()
