# %% [markdown]
# ## Horizonal divergence pdfs by Pope regime
#
# This code views the pdfs of horizontal divergence generated by Multidop/dask over the CPOL/Berrima dataset.

# %%
from netCDF4 import Dataset
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
deep_west_file = '/home/rjackson/data/divpdfregime0_varble.cdf'
moist_east_file = '/home/rjackson/data/divpdfregime1_varble.cdf'
east_file = '/home/rjackson/data/divpdfregime2_varble.cdf'
dry_east_file = '/home/rjackson/data/divpdfregime3_varble.cdf'
shallow_west_file = '/home/rjackson/data/divpdfregime4_varble.cdf'

# %%
# Deep west
deep_west_cdf = Dataset(deep_west_file, 'r')
mean_dw = deep_west_cdf.variables['mean'][:]
median_dw = deep_west_cdf.variables['median'][:]
ninety_dw = deep_west_cdf.variables['ninety'][:]
ninety_five_dw = deep_west_cdf.variables['ninety_five'][:]
ninety_nine_dw = deep_west_cdf.variables['ninety_nine'][:]
z_dw = deep_west_cdf.variables['z'][:]
five_dw = deep_west_cdf.variables['five'][:]
one_dw = deep_west_cdf.variables['one'][:]
ten_dw = deep_west_cdf.variables['ten'][:]
deep_west_cdf.close()

# Moist east
moist_east_cdf = Dataset(moist_east_file, 'r')
mean_me = moist_east_cdf.variables['mean'][:]
median_me = moist_east_cdf.variables['median'][:]
ninety_me = moist_east_cdf.variables['ninety'][:]
ninety_five_me = moist_east_cdf.variables['ninety_five'][:]
ninety_nine_me = moist_east_cdf.variables['ninety_nine'][:]
z_me = moist_east_cdf.variables['z'][:]
five_me = moist_east_cdf.variables['five'][:]
one_me = moist_east_cdf.variables['one'][:]
ten_me = moist_east_cdf.variables['ten'][:]
moist_east_cdf.close()

# East
east_cdf = Dataset(east_file, 'r')
mean_e = east_cdf.variables['mean'][:]
median_e = east_cdf.variables['median'][:]
ninety_e = east_cdf.variables['ninety'][:]
ninety_five_e = east_cdf.variables['ninety_five'][:]
ninety_nine_e = east_cdf.variables['ninety_nine'][:]
z_e = east_cdf.variables['z'][:]
five_e = east_cdf.variables['five'][:]
one_e = east_cdf.variables['one'][:]
ten_e = east_cdf.variables['ten'][:]
east_cdf.close()

# Dry east
dry_east_cdf = Dataset(dry_east_file, 'r')
mean_de = dry_east_cdf.variables['mean'][:]
median_de = dry_east_cdf.variables['median'][:]
ninety_de = dry_east_cdf.variables['ninety'][:]
ninety_five_de = dry_east_cdf.variables['ninety_five'][:]
ninety_nine_de = dry_east_cdf.variables['ninety_nine'][:]
z_de = dry_east_cdf.variables['z'][:]
five_de = dry_east_cdf.variables['five'][:]
one_de = dry_east_cdf.variables['one'][:]
ten_de = dry_east_cdf.variables['ten'][:]
dry_east_cdf.close()

# Shallow west
shallow_west_cdf = Dataset(shallow_west_file, 'r')
mean_sw = shallow_west_cdf.variables['mean'][:]
median_sw = shallow_west_cdf.variables['median'][:]
ninety_sw = shallow_west_cdf.variables['ninety'][:]
ninety_five_sw = shallow_west_cdf.variables['ninety_five'][:]
ninety_nine_sw = shallow_west_cdf.variables['ninety_nine'][:]
z_sw = shallow_west_cdf.variables['z'][:]
five_sw = shallow_west_cdf.variables['five'][:]
one_sw = shallow_west_cdf.variables['one'][:]
ten_sw = shallow_west_cdf.variables['ten'][:]
shallow_west_cdf.close()

# %%
plt.figure(figsize=(14,14))
plt.subplot(321)
plt.plot(mean_dw,z_dw,linewidth=2)
plt.plot(median_dw,z_dw,linewidth=2)
plt.plot(ninety_dw,z_dw,linewidth=2)
plt.plot(ninety_five_dw, z_dw,linewidth=2)
plt.plot(ninety_nine_dw, z_dw,linewidth=2)
plt.plot(one_dw, z_sw, linewidth=2)
plt.plot(five_dw, z_sw, linewidth=2)
plt.plot(ten_dw, z_sw, linewidth=2)
plt.xlim([-1e-5,2e-5])
plt.ylim([0,20000])
plt.title('Deep west')
plt.xlabel('divergence [1/s]')
plt.ylabel('Z [m]')
plt.legend(['Mean', 'Median', '90', '95', '99', '1', '5','10'])

plt.subplot(322)
plt.plot(mean_me,z_me,linewidth=2)
plt.plot(median_me,z_me,linewidth=2)
plt.plot(ninety_me,z_me,linewidth=2)
plt.plot(ninety_five_me, z_me,linewidth=2)
plt.plot(ninety_nine_me, z_me,linewidth=2)
plt.plot(one_me, z_me, linewidth=2)
plt.plot(five_me, z_me, linewidth=2)
plt.plot(ten_me, z_me, linewidth=2)
plt.xlim([-1e-5,2e-5])
plt.ylim([0,20000])
plt.title('Moist east')
plt.xlabel('divergence [1/s]')
plt.ylabel('Z [m]')

plt.subplot(323)
plt.plot(mean_e,z_e,linewidth=2)
plt.plot(median_e,z_e,linewidth=2)
plt.plot(ninety_e,z_e,linewidth=2)
plt.plot(ninety_five_e, z_e,linewidth=2)
plt.plot(ninety_nine_e, z_e,linewidth=2)
plt.plot(one_e, z_e, linewidth=2)
plt.plot(five_e, z_e, linewidth=2)
plt.plot(ten_e, z_e, linewidth=2)
plt.xlim([-1e-5,2e-5])
plt.ylim([0,20000])
plt.title('East')
plt.xlabel('divergence [1/s]')
plt.ylabel('Z [m]')

plt.subplot(324)
plt.plot(mean_de,z_de,linewidth=2)
plt.plot(median_de,z_de,linewidth=2)
plt.plot(ninety_de,z_de,linewidth=2)
plt.plot(ninety_five_de, z_de,linewidth=2)
plt.plot(ninety_nine_de, z_de,linewidth=2)
plt.plot(one_de, z_de, linewidth=2)
plt.plot(five_de, z_de, linewidth=2)
plt.plot(ten_de, z_de, linewidth=2)
plt.xlim([-1e-5,2e-5])
plt.ylim([0,20000])
plt.title('Dry East')
plt.xlabel('divergence [1/s]')
plt.ylabel('Z [m]')

plt.subplot(325)
plt.plot(mean_sw,z_sw,linewidth=2)
plt.plot(median_sw,z_sw,linewidth=2)
plt.plot(ninety_sw,z_sw,linewidth=2)
plt.plot(ninety_five_sw, z_sw,linewidth=2)
plt.plot(ninety_nine_sw, z_sw,linewidth=2)
plt.plot(one_sw, z_sw, linewidth=2)
plt.plot(five_sw, z_sw, linewidth=2)
plt.plot(ten_sw, z_sw, linewidth=2)
plt.xlim([-1e-5,2e-5])
plt.ylim([0,20000])
plt.title('Shallow West')
plt.xlabel('divergence [1/s]')
plt.ylabel('Z [m]')

# %%
plt.figure(figsize=(14,21))
plt.subplot(421)
plt.plot(median_dw,z_dw,linewidth=2)
plt.plot(median_me,z_me,linewidth=2)
plt.plot(median_e,z_e,linewidth=2)
plt.plot(median_de,z_de,linewidth=2)
plt.plot(median_sw,z_sw,linewidth=2)
plt.legend(['DW','ME','E','DE','SW'], loc='best')
plt.xlim([-2e-5,1e-5])
plt.title('Median')
plt.xlabel('divergence [1/s]')
plt.ylabel('Z [m]')

plt.subplot(422)
plt.plot(mean_dw,z_dw,linewidth=2)
plt.plot(mean_me,z_me,linewidth=2)
plt.plot(mean_e,z_e,linewidth=2)
plt.plot(mean_de,z_de,linewidth=2)
plt.plot(mean_sw,z_sw,linewidth=2)
plt.xlim([-2e-5,2e-5])
plt.title('Mean')
plt.xlabel('divergence [1/s]')
plt.ylabel('Z [m]')
plt.subplot(423)
plt.plot(ninety_dw,z_dw,linewidth=2)
plt.plot(ninety_me,z_me,linewidth=2)
plt.plot(ninety_e,z_e,linewidth=2)
plt.plot(ninety_de,z_de,linewidth=2)
plt.plot(ninety_sw,z_sw,linewidth=2)
plt.xlim([-2e-5,2e-5])
plt.xlabel('divergence [1/s]')
plt.ylabel('Z [m]')
plt.title('90%')

plt.subplot(424)
plt.plot(ninety_five_dw,z_dw,linewidth=2)
plt.plot(ninety_five_me,z_me,linewidth=2)
plt.plot(ninety_five_e,z_e,linewidth=2)
plt.plot(ninety_five_de,z_de,linewidth=2)
plt.plot(ninety_five_sw,z_sw,linewidth=2)
plt.xlabel('divergence [1/s]')
plt.xlim([-2e-5,2e-5])

plt.title('95%')
plt.subplot(425)
plt.plot(ninety_nine_dw,z_dw,linewidth=2)
plt.plot(ninety_nine_me,z_me,linewidth=2)
plt.plot(ninety_nine_e,z_e,linewidth=2)
plt.plot(ninety_nine_de,z_de,linewidth=2)
plt.plot(ninety_nine_sw,z_sw,linewidth=2)
plt.xlim([-2e-5,2e-5])
plt.title('99%')
plt.xlabel('divergence [1/s]')
plt.ylabel('Z [m]')

plt.subplot(426)
plt.plot(one_dw,z_dw,linewidth=2)
plt.plot(one_me,z_me,linewidth=2)
plt.plot(one_e,z_e,linewidth=2)
plt.plot(one_de,z_de,linewidth=2)
plt.plot(one_sw,z_sw,linewidth=2)
plt.xlim([-2e-5,2e-5])
plt.title('1%')
plt.xlabel('divergence [1/s]')
plt.ylabel('Z [m]')

plt.subplot(427)
plt.plot(five_dw,z_dw,linewidth=2)
plt.plot(five_me,z_me,linewidth=2)
plt.plot(five_e,z_e,linewidth=2)
plt.plot(five_de,z_de,linewidth=2)
plt.plot(five_sw,z_sw,linewidth=2)
plt.xlim([-2e-5,2e-5])
plt.title('5%')
plt.xlabel('divergence [1/s]')
plt.ylabel('Z [m]')

plt.subplot(428)
plt.plot(ten_dw,z_dw,linewidth=2)
plt.plot(ten_me,z_me,linewidth=2)
plt.plot(ten_e,z_e,linewidth=2)
plt.plot(ten_de,z_de,linewidth=2)
plt.plot(ten_sw,z_sw,linewidth=2)
plt.xlim([-2e-5,2e-5])
plt.title('10%')
plt.xlabel('divergence [1/s]')
plt.ylabel('Z [m]')
